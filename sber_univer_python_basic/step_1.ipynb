# %%
print("Hello\'x World!")
var = "first" #asdasd
print(var)
asd = 2 + 9
print(asd)
# Out:
# Hello'x World!
# first
# 11

# %%
sd = 3
if sd < 3:
    print("less")
elif sd > 5:
    print("more then 5")
else:
    print ("more then 3 but less then 5")
# Out:
# more then 3 but less then 5
