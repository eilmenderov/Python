# %%
var1 = input("Ведите данные\n")
var2 = input("Ведите данные\n")
if (var1 > var2):
    print(var2)
else:
    print(var1)
# Out:
# Ведите данные
# 5
# Ведите данные
# 16
# 16

# %%
var1 = -5
var2 = -3
var3 = -3
if (var1 < var2 and var1 < var3):
    print("smalest =", var1)
elif (var2 < var1 and var1 < var3):
    print("smalest =", var2)
else:
    print("smalest =", var3)
# Out:
# smalest = -5

# %%
var1 = 10
var2 = 10
var3 = 10
if (var1 == var2 and var1 == var3):
    print("rez =", 3)
elif (var2 == var1 or var1 == var3 or var3 == var2):
    print("rez =", 2)
else:
    print("rez =", 0)
# Out:
# rez = 3
