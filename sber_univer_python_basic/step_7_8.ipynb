# %%
# Task 1
str = "Abraсadabra"
print(str[2]) #Вывести третий символ этой строки.
print(str[len(str) - 2]) #Вывести предпоследний символ этой строки.
print(str[:5]) #Вывести первые пять символов этой строки.
print(str[:len(str) - 2]) #Вывести строку, кроме последних двух символов.
print(str[::2]) #Вывести все символы с четными индексами (считайте, что 0 - четный индекс).
print(str[1::2]) #Вывести все символы с нечетными индексами.
print(str[::-1]) #Вывести все символы в обратном порядке.
print(str[::-2]) #Вывести все символы строки через один в обратном порядке, начиная с последнего.
print(len(str)) #Вывести длину данной строки
# Out:
# r
# r
# Abraс
# Abraсadab
# Arсdba
# baaar
# arbadaсarbA
# abdсrA
# 11

# %%
# Task 2
# Напишите код, который обрабатывает строковые данные и возвращает их с первыми
# заглавными буквами в каждом слове.
str =  'can    You   solve  it?'
tmp = str.split()
str = str.title()
rez = ""
i = 0
while (i < len(tmp)):
    if ((tmp[i][0]).isalpha() == True):
        tmp[i] = tmp[i].title()
    i += 1
i = 0
while (i < len(tmp)):
    rez = rez + tmp[i]
    i += 1
    if (i != len(tmp)):
        rez = rez + " "
print(rez)
# Out:
# Can You Solve It?

# %%
# Task 3
# Напишите код, который обрабатывает строковые данные и выводит сообщение о том,
# надежен ли пароль или нет. В случае, еслипароль не надежен, код должен выдавать
# рекомендации для усиления надежности пароля.
pas = "@PowerRangers123@"
spec = "!@#$%^&*()-+"
num = "1234567890"
low = 'abcdefghijklmnopqrstuvwxyz'
up = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
if (len(pas) >= 12 and pas.isdigit() and pas.islower() and pas.isupper() )
