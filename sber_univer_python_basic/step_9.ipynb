# %%
# Task 1 Задан список с числами. 
# Напишите программу, которая выводит все элементы списка с четными индексами в виде нового списка.
n = int(input('Введите длину списка: '))
a = []
for i in range(n):
    a.append(int(input('Введите число №'+str(i+1)+': ')))
rez = []
len_a = n
i = 0
while (i < len_a):
    if (i % 2 == 0):
        rez.append(a[i])
    i += 1
print(rez)
# Out:
# ['1', '3', '5']

# %%
# Task 2 Задан список с числами.
# Напишите программу, которая выводит все элементы списка, которые больше предыдущего, в виде отдельного списка.
n = int(input('Введите длину списка: '))
a = []
for i in range(n):
    a.append(int(input('Введите число №'+str(i+1)+': ')))
rez = []
len_a = n
i = 1
while (i < len_a):
    if (a[i] > a[i - 1]):
        rez.append(a[i])
    i += 1
print(rez)
# Out:
# Введите длину списка: 3
# Введите число №1: 1
# Введите число №2: 3
# Введите число №3: 2
# [3]

# %%
# Task 3 Задан список с числами.
# Напишите программу, которая меняет местами наибольший и наименьший элемент и выводит новый список.
n = int(input('Введите длину списка: '))
a = []
for i in range(n):
    a.append(int(input('Введите число №'+str(i+1)+': ')))
len_a = n
min_a = a[0]
max_a = a[0]
i = 1
while (i < len_a):
    if (max_a < a[i]):
        max_a = a[i]
    if (min_a > a[i]):
        min_a = a[i]
    i += 1
ind_max = a.index(max_a)
ind_min = a.index(min_a)
a.pop(ind_max)
a.insert(ind_max, min_a)
a.remove(min_a)
a.insert(ind_min, max_a)
print(a)
# Out:
# Введите длину списка: 2
# Введите число №1: 5
# Введите число №2: 6
# [6, 5]
