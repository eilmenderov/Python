# %%
null_var = None
not_null_var = "some"
if null_var == None:
    print("null_var is None")
else:
    print("null_var is not None")
if not_null_var == None:
    print("not_null_var is None")
else:
    print("not_null_var is not None")
# Out:
# null_var is None
# not_null_var is not None

# %%
a = 0
b = 0
print(a < b)
print(a == b)
# Out:
# False
# True

# %%
type(None)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(1)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type(5 + 4j)
# Out:
# complex

# %%
type([1, 5.3, False, 4])
# Out:
# list

# %%
type((1, True, 3, 5+4j))
# Out:
# tuple

# %%
type(range(5))
# Out:
# range

# %%
type('Hello')
# Out:
# str

# %%
type(b'a')
# Out:
# bytes

# %%
type(bytearray([1,2,3]))
# Out:
# bytearray

# %%
type(memoryview(bytearray('XYZ', 'utf-8')))
# Out:
# memoryview

# %%
type({'a', 3, True})
# Out:
# set

# %%
type(frozenset({1, 2, 3}))
# Out:
# frozenset

# %%
type({'a' : 32})
# Out:
# dict
